# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from prophet import Prophet
# Out:
# Requirement already satisfied: prophet in c:\users\lucan\anaconda3\lib\site-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\lucan\anaconda3\lib\site-packages (from prophet) (1.2.4)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\lucan\anaconda3\lib\site-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\lucan\anaconda3\lib\site-packages (from prophet) (3.8.0)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\lucan\anaconda3\lib\site-packages (from prophet) (2.1.4)
# Requirement already satisfied: holidays>=0.25 in c:\users\lucan\anaconda3\lib\site-packages (from prophet) (0.52)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\lucan\anaconda3\lib\site-packages (from prophet) (4.65.0)
# Requirement already satisfied: importlib-resources in c:\users\lucan\anaconda3\lib\site-packages (from prophet) (6.4.0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\users\lucan\anaconda3\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.0)
# Requirement already satisfied: python-dateutil in c:\users\lucan\anaconda3\lib\site-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lucan\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lucan\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lucan\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lucan\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lucan\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lucan\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lucan\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lucan\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lucan\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2023.3)
# Requirement already satisfied: colorama in c:\users\lucan\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\lucan\anaconda3\lib\site-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
dados = yf.download('JNJ', start='2020-01-01', end='2023-12-31', progress=False)
dados = dados.reset_index()
dados
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-01-02  145.869995  146.020004  145.080002  145.970001  129.055923
# 1    2020-01-03  143.500000  145.369995  143.000000  144.279999  127.561707
# 2    2020-01-06  144.000000  144.199997  142.850006  144.100006  127.402626
# 3    2020-01-07  144.009995  145.449997  141.380005  144.979996  128.180603
# 4    2020-01-08  144.869995  145.979996  143.699997  144.960007  128.162949
# ...         ...         ...         ...         ...         ...         ...
# 1001 2023-12-22  155.250000  156.529999  155.020004  155.460007  153.051376
# 1002 2023-12-26  155.000000  156.350006  154.850006  156.139999  153.720825
# 1003 2023-12-27  155.500000  156.520004  155.419998  156.350006  153.927582
# 1004 2023-12-28  156.000000  157.240005  155.990005  156.580002  154.154007
# 1005 2023-12-29  156.509995  156.899994  155.979996  156.740005  154.311539
#
#        Volume
# 0     5777000
# 1     5752400
# 2     7731300
# 3     7382900
# 4     6605800
# ...       ...
# 1001  3798500
# 1002  4170000
# 1003  5288100
# 1004  4377500
# 1005  4311100
#
# [1006 rows x 7 columns]

# %%
dados_treino = dados[dados['Date'] < '2023-07-31']
dados_teste = dados[dados['Date'] >= '2023-07-31']

# %%
dados_prophet_treino = dados_treino[['Date', 'Close']].rename(columns={'Date':'ds', 'Close':'y'})
dados_prophet_treino
# Out:
#             ds           y
# 0   2020-01-02  145.970001
# 1   2020-01-03  144.279999
# 2   2020-01-06  144.100006
# 3   2020-01-07  144.979996
# 4   2020-01-08  144.960007
# ..         ...         ...
# 894 2023-07-24  171.080002
# 895 2023-07-25  172.389999
# 896 2023-07-26  172.720001
# 897 2023-07-27  173.690002
# 898 2023-07-28  174.479996
#
# [899 rows x 2 columns]

# %%
modelo = Prophet(weekly_seasonality=True,
                yearly_seasonality=True,
                daily_seasonality=False)

modelo.add_country_holidays(country_name='US')

modelo.fit(dados_prophet_treino)
# Out:
# 23:22:47 - cmdstanpy - INFO - Chain [1] start processing
# 23:22:49 - cmdstanpy - INFO - Chain [1] done processing

# %%
futuro = modelo.make_future_dataframe(periods=150)
previsao = modelo.predict(futuro)

# %%
plt.figure(figsize=(14, 8))
plt.plot(dados_treino['Date'], dados_treino['Close'], label='Dados de Treino', color='blue')
plt.plot(dados_teste['Date'], dados_teste['Close'], label='Dados Reais (teste)', color='green')
plt.plot(previsao['ds'], previsao['yhat'], label='Previsão', color='orange', linestyle='--')

plt.axvline(dados_treino['Date'].max(), color='red', linestyle='--', label='Início da Previsão')
plt.xlabel('Data')
plt.ylabel('Preço de Fechamento')
plt.title('Previsão de Preço de Fechamento vs Dados Reais')
plt.legend()
plt.show()
